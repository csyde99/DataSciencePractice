# %%
import pandas as pd

# %%
chipotle_data = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')
chipotle_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipotle_data.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipotle_data.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipotle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipotle_data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
cd = chipotle_data.groupby('item_name')
cd = cd.sum()
cd = cd.sort_values(['quantity'], ascending=False)
cd = cd.head(1)
cd
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
chd = chipotle_data.groupby('choice_description')
chd = chd.sum()
chd = chd.sort_values(['quantity'], ascending=False)
chd.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
dollar = lambda x: float(x[1:-1])
chipotle_data.item_price = chipotle_data.item_price.apply(dollar)
chipotle_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
 chipotle_data['total_price'] = (chipotle_data['quantity'] * chipotle_data['item_price'])
 total = chipotle_data['total_price'].sum()
print('Total Revenue: $' + str(total) )
# Out:
# Total Revenue: $39237.02

# %%
chipotle_data.columns
df = chipotle_data[['item_name', 'choice_description']]
df
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4617                          Steak Burrito
# 4618                          Steak Burrito
# 4619                     Chicken Salad Bowl
# 4620                     Chicken Salad Bowl
# 4621                     Chicken Salad Bowl
#
#                                      choice_description
# 0                                                   NaN
# 1                                          [Clementine]
# 2                                               [Apple]
# 3                                                   NaN
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# ...                                                 ...
# ...

# %%
cd = chipotle_data.groupby('item_name')
cd_burrito = filtered[cd.item_name == 'Nantucket Nectar']
cd_burrito
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-2cf96ee817a3> in <module>
# ...

# %%
filtered = chipotle_data.drop_duplicates(['item_name', 'quantity'])
one_prod = filtered[filtered.quantity == 1]
df=one_prod[['item_name', 'item_price']]
df_sort = df.sort_values(by = 'item_price', ascending=False)
chipotle_data.sort_values(by="item_price", ascending=False).head(1)
chipotle_data.sort_values(by="quantity", ascending=False).head(1)
chipotle_data.sort_values(by="total_price").head(1)
burrito = chipotle_data.groupby('item_name').sum()
#burritoInfo = filtered[burrito.item_name == "Burrito"]   ## will fix this - trying to retrieve only burrito row- finding out how much is the revenue from Only burrito
df = chipotle_data.groupby('item_name').sum()
df[df.order_id == 472 ]  
#df[df.item_name == 'Veggie Salad']
cd = chipotle_data[chipotle_data.item_name == "Burrito"]
cd1 = cd[cd.total_price].sum()
cd1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-387d98dfa92f> in <module>
#      12 #df[df.item_name == 'Veggie Salad']
#      13 cd = chipotle_data[chipotle_data.item_name == "Burrito"]
# ---> 14 cd1 = cd[cd.total_price].sum()
#      15 cd1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Syamala'
